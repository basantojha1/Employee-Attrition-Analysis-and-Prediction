# %% [markdown]
# # Employee Attrition Predictive Analytics

# %%
# Importing Pandas and Numpy library
import numpy as np
import pandas as pd

# %%
# Loading the dataset 
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
# Displaying first few rows of the dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
# Display the summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Note:- We don't have any null values in the dataframe
#         So, We dont have to deal with any missing values.

# %%
# Displaying descriptive statics of the dataframe
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Checking for duplicates
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Checking datatypes to find outliers present in the numeric columns
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# Checking for outliers using IQR method
# Creating a numeric column
numeric_column = ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 
             'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 
             'PercentSalaryHike','PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 
             'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 
             'YearsSinceLastPromotion', 'YearsWithCurrManager']

# Calculating Q1 and Q3
Q1 = df[numeric_column].quantile(0.25)
Q3 = df[numeric_column].quantile(0.75)

# Calculating InterQuartile
IQR = Q3 - Q1

#Setting upper and lower bounds
lower_bound = (Q1 - 1.5 * IQR)
upper_bound = (Q3 + 1.5 * IQR)

# Checking Outliers
outliers = ((df[numeric_column] < lower_bound) | (df[numeric_column] > upper_bound)).any(axis=1)
df[outliers]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1457   40        No      Travel_Rarely       1194  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
# 1462   39        No      Travel_Rarely        722                   Sales
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [raw]
# Note:- Alternatively, We can check for outliers using z-score method as well

# %% [markdown]
# # Visualizaiton

# %%
# Importing visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Visualizing distribution of numerical columns
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

# %%
# Histogram plot
for feature in numerical_features:
    plt.figure(figsize=(8, 6))
    plt.subplot(2, 2, 2)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Histogram of {feature}')
# Out:
# C:\Users\Basan\AppData\Local\Temp\ipykernel_11880\1339120590.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))

# %%
# Box plot
for feature in numerical_features:
    plt.figure(figsize=(8,6))
    plt.subplot(2, 2, 2)
    sns.boxplot(data=df, x=feature)
    plt.title(f'Boxplot of {feature}')
    plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [raw]
# Getting better understanding of the data

# %%
# Number of unique values in Attrition
df['Attrition'].nunique()
# Out:
# 2

# %%
# Value count
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %% [raw]
# Note:- Here, we can see that the total number of employee who have left the company is 237.
#         And 1233 are still in the company.

# %% [markdown]
# # Univariate Analysis

# %% [raw]
# Before diving into more complex analysis, it is essential to understand individual variables in your dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Extracting the column
BusinessTravel_column = df['BusinessTravel']

# Getting value counts
BusinessTravel_counts = BusinessTravel_column.value_counts()

# Plotting bargraph
plt.figure(figsize=(6, 4))
BusinessTravel_counts.plot(kind='bar')
plt.title('Business Travel')
plt.xticks(rotation=0)
plt.show()

# %%
# Extracting the column
Department_column = df['Department']

# Getting value counts
Department_counts = Department_column.value_counts()

# Plotting bargraph
plt.figure(figsize=(6, 4))
Department_counts.plot(kind='bar')
plt.title('Department Travel')
plt.xticks(rotation=0)
plt.show()

# %%
# Extracting the column
EducationField_column = df['EducationField']

# Getting value counts
EducationField_counts = EducationField_column.value_counts()

# Plotting bargraph
plt.figure(figsize=(6, 4))
EducationField_counts.plot(kind='bar')
plt.title('Education Field')
plt.xticks(rotation=45)
plt.show()

# %%
# Extracting the column
JobRole_column = df['JobRole']

# Getting value counts
JobRole_counts = JobRole_column.value_counts()

# Plotting bargraph
plt.figure(figsize=(6, 4))
JobRole_counts.plot(kind='bar')
plt.title('JobRole')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Plotting a linear line across a scatter plot
# Importing sklearn linear regression model 
from sklearn.linear_model import LinearRegression

# Step 1: Fit a linear regression model
x = df[['Age']]
y = df[['MonthlyIncome']]

model = LinearRegression()
model.fit(x, y)

# Step 2: Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['MonthlyIncome'], color='blue', alpha=0.5, label='Data Points')

# Step 3: Plot the linear line
plt.plot(x, model.predict(x), color='blue', label='Linear Regression')

plt.title('Scatter Plot of Age vs Monthly Income with Linear Regression')
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Distribution of monthly income for each department
plt.figure(figsize=(8, 6))
sns.boxplot(x='Department', y='MonthlyIncome', data=df)
plt.title('Boxplot of Monthly Income by Department')
plt.xlabel('Departments')
plt.ylabel('Monthly Income')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
# Step 1: Fit a linear regression model
x = df[['PerformanceRating']]
y = df[['PercentSalaryHike']]

model = LinearRegression()
model.fit(x, y)

# Step 2: Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['PerformanceRating'], df['PercentSalaryHike'], color='blue', alpha=0.5, label='Data Points')

# Step 3: Plot the linear line
plt.plot(x, model.predict(x), color='blue', label='Linear Regression')

plt.title('Scatter Plot of Performance Rating vs PercentSalaryHike with Linear Regression')
plt.xlabel('Preformance Rating')
plt.ylabel('Percent Salary Hike')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# Create a heatmap to check correlation between various columns
plt.figure(figsize=(16, 10))
sns.heatmap(df[numeric_column].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Feature engineering

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Encoding values for Attrition (Yes, No) to (1, 0)
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
df['Attrition'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Gender Column unique values
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Performing one-hot encoding on the 'Gender' column
gender_encoded = pd.get_dummies(df['Gender'], prefix='Gender')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df, gender_encoded], axis=1)

# Dropping the original 'Gender' column
df_encoded.drop('Gender', axis=1, inplace=True)

# %%
# MaritalStatus Column unique values
df['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
# Performing one-hot encoding on the 'MaritalStatus' column
marital_status_encoded = pd.get_dummies(df['MaritalStatus'], prefix='MaritalStatus')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df_encoded, marital_status_encoded], axis=1)

# Drop the original 'MaritalStatus' column
df_encoded.drop('MaritalStatus', axis=1, inplace=True)

# %%
# Encoding values for Over18 'Yes' to '1'
df_encoded['Over18'] = df_encoded['Over18'].map({'Y': 1})

# %%
# OverTime Column unique values
df_encoded['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Encoding values for OverTime ('Yes', 'No') to (1, 0)
df_encoded['OverTime'] = df_encoded['OverTime'].map({'Yes': 1, 'No': 0})

# %%
# BusinessTravel Column unique values
df_encoded['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
# Performing one-hot encoding on the 'BusinessTravel' column
business_travel_encoded = pd.get_dummies(df['BusinessTravel'], prefix='BusinessTravel')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df_encoded, business_travel_encoded], axis=1)

# Drop the original 'BusinessTravel' column
df_encoded.drop('BusinessTravel', axis=1, inplace=True)

# %%
# Department Column unique values
df_encoded['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
# Performing one-hot encoding on the 'Department' column
department_encoded = pd.get_dummies(df['Department'], prefix='Department')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df_encoded, department_encoded], axis=1)

# Drop the original 'Department' column
df_encoded.drop('Department', axis=1, inplace=True)

# %%
# EducationField Column unique values
df_encoded['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
# Performing one-hot encoding on the 'EducationField' column
education_field_encoded = pd.get_dummies(df['EducationField'], prefix='EducationField')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df_encoded, education_field_encoded], axis=1)

# Drop the original 'EduactionField' column
df_encoded.drop('EducationField', axis=1, inplace=True)

# %%
# JobRole Column unique values
df_encoded['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
# Performing one-hot encoding on the 'JobRole' column
job_role_encoded = pd.get_dummies(df['JobRole'], prefix='JobRole')

# Concatenating the encoded columns with the DataFrame
df_encoded = pd.concat([df_encoded, job_role_encoded], axis=1)

# Drop the original 'JobRole' column
df_encoded.drop('JobRole', axis=1, inplace=True)

# %%
# Encoded dataframe
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   Attrition                          1470 non-null   int64
#  2   DailyRate                          1470 non-null   int64
#  3   DistanceFromHome                   1470 non-null   int64
#  4   Education                          1470 non-null   int64
#  5   EmployeeCount                      1470 non-null   int64
#  6   EmployeeNumber                     1470 non-null   int64
#  7   EnvironmentSatisfaction            1470 non-null   int64
#  8   HourlyRate                         1470 non-null   int64
#  9   JobInvolvement                     1470 non-null   int64
#  10  JobLevel                           1470 non-null   int64
# ...

# %% [markdown]
# # Data Modeling

# %%
# Trying out Logistic Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Splitting data into features and target variable
x = df_encoded.drop('Attrition', axis=1)  # Features
y = df_encoded['Attrition']  # Target variable

# Splitting data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initializing the logistic regression model
logreg = LogisticRegression(max_iter=1000)  # Can adjust maximum itteration

# Fitting the model on the training data
logreg.fit(x_train, y_train)

# Maing predictions on the test set
y_predict = logreg.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_predict)
print("Accuracy of Logistic Regression Model:", accuracy)
# Out:
# Accuracy of Logistic Regression Model: 0.8639455782312925
# C:\Users\Basan\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Trying out Decision Tree
# Importing Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Instantiating the DecisionTreeClassifier
tree_model = DecisionTreeClassifier(random_state=42)

# Training the model
tree_model.fit(x_train, y_train)

# Predicting on the test data
y_predict_tree = tree_model.predict(x_test)

# Calculate accuracy
accuracy_tree = accuracy_score(y_test, y_predict_tree)
print("Decision Tree Model Accuracy:", accuracy_tree)
# Out:
# Decision Tree Model Accuracy: 0.7653061224489796

# %%
# Importing random forest libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Splitting the data into features (x) and target variable (y)
x = df_encoded.drop(columns=['Attrition'])  # Features
y = df_encoded['Attrition']  # Target variable

# Splitting the data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initializing the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Training the classifier on the training data
rf_classifier.fit(x_train, y_train)

# Predicting the target variable on the testing data
y_pred = rf_classifier.predict(x_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Generating classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Generating confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8809523809523809
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       255
#            1       0.83      0.13      0.22        39
#
#     accuracy                           0.88       294
#    macro avg       0.86      0.56      0.58       294
# weighted avg       0.88      0.88      0.84       294
#
#
# Confusion Matrix:
# [[254   1]
#  [ 34   5]]

# %%
# Importing naive bayes libraries
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Splitting the data into features (x) and target variable (y)
x = df_encoded.drop(columns=['Attrition'])  # Features
y = df_encoded['Attrition']  # Target variable

# Splitting the data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initializing the Naive Bayes classifier (GaussianNB for numerical features)
nb_classifier = GaussianNB()

# Training the classifier on the training data
nb_classifier.fit(x_train, y_train)

# Predicting the target variable on the testing data
y_predict = nb_classifier.predict(x_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_predict)
print("Accuracy:", accuracy)

# Generating classification report
print("\nClassification Report:")
print(classification_report(y_test, y_predict))

# Generating confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_predict))
# Out:
# Accuracy: 0.7619047619047619
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       255
#            1       0.30      0.59      0.40        39
#
#     accuracy                           0.76       294
#    macro avg       0.61      0.69      0.62       294
# weighted avg       0.84      0.76      0.79       294
#
#
# Confusion Matrix:
# [[201  54]
#  [ 16  23]]
